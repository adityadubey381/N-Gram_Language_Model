# %% [markdown]
# #Step 1 – Environment Setup

# %%
import torch
import random
import re
from nltk.tokenize import word_tokenize

# %% [markdown]
# #Step 2 – Prepare Dataset

# %%
filepath = r"datasets.txt"
with open(filepath, 'r', encoding="utf-8") as f:
  text=f.read().lower()

# %%
text
# Out:
# 'implementation of a simple n-gram language model using python\n1. introduction\n\nlanguage is one of the most fundamental ways humans communicate information, ideas, and knowledge. in the field of artificial intelligence (ai) and natural language processing (nlp), enabling computers to understand and generate human language is a major research goal. one important concept in nlp is the language model, which is a mathematical model that predicts the probability of a sequence of words. language models are used in many applications such as chatbots, machine translation, speech recognition, text prediction, and virtual assistants.\n\na language model learns patterns from a given dataset and uses these patterns to generate or predict text. modern language models such as gpt and bert rely on deep learning and massive datasets. however, before the rise of deep learning models, simpler statistical approaches were widely used. one of the most important and fundamental approaches is the n-gram language model.\n\nthe purpose of this project is to implement a simple language model using the n-gram approach in python. the model learns word patterns from a text dataset and generates new sentences based on the learned patterns. the goal of this assignment is not to build a highly sophisticated ai model, but to demonstrate understanding of core concepts such as tokenization, statistical word prediction, and probability-based text generation.\n\nthe implementation focuses on a bigram model (n = 2), though the system can also be extended to support trigram or higher-order n-grams. the program reads a dataset from a text file, processes the text, trains the language model, and generates sentences based on learned word relationships.\n\nthis project demonstrates the basic principles behind language modeling and provides a foundation for understanding more advanced nlp models.\n\n2. objectives of the project\n\nthe primary objective of this project is to design and implement a simple n-gram language model using python. the model should be able to learn patterns from a text dataset and generate new sentences based on those patterns.\n\nthe specific objectives of the project are as follows:\n\nto understand the concept of language models in natural language processing.\n\nto implement text preprocessing and tokenization.\n\nto build an n-gram model that learns word patterns from the dataset.\n\nto generate sentences using learned probabilities of word sequences.\n\nto organize the implementation into clean and modular python functions.\n\nto test the model by generating multiple example sentences.\n\nby achieving these objectives, the project demonstrates basic machine learning concepts and python programming skills required for ai and nlp development.\n\n3. technologies and tools used\n\nthe following technologies and tools were used to implement this project:\n\npython 3\n\npython was chosen as the primary programming language due to its simplicity, readability, and extensive ecosystem for data science and artificial intelligence.\n\npython standard libraries\n\nseveral built-in python libraries were used in the project:\n\ncollections – used to implement defaultdict for storing word relationships.\n\nrandom – used for selecting the next word randomly from possible candidates.\n\nre – used for text preprocessing and removing punctuation.\n\noptional libraries\n\nalthough not strictly required, libraries such as numpy and pandas can be used for more advanced data handling. in this project, the core implementation relies mainly on standard python libraries to keep the model simple and lightweight.\n\n4. dataset preparation\n\nthe first step in building the language model is preparing the dataset. the dataset consists of a simple text file named dataset.txt, which contains multiple sentences related to technology, programming, and machine learning.\n\nan example dataset used in this project is shown below:\n\nmachine learning is fascinating\npython i ...

# %% [markdown]
# # Step 3 – Text Processing

# %%
# remove newline characters
text = text.replace("\n", " ")
text
# Out:
# 'implementation of a simple n-gram language model using python 1. introduction  language is one of the most fundamental ways humans communicate information, ideas, and knowledge. in the field of artificial intelligence (ai) and natural language processing (nlp), enabling computers to understand and generate human language is a major research goal. one important concept in nlp is the language model, which is a mathematical model that predicts the probability of a sequence of words. language models are used in many applications such as chatbots, machine translation, speech recognition, text prediction, and virtual assistants.  a language model learns patterns from a given dataset and uses these patterns to generate or predict text. modern language models such as gpt and bert rely on deep learning and massive datasets. however, before the rise of deep learning models, simpler statistical approaches were widely used. one of the most important and fundamental approaches is the n-gram language model.  the purpose of this project is to implement a simple language model using the n-gram approach in python. the model learns word patterns from a text dataset and generates new sentences based on the learned patterns. the goal of this assignment is not to build a highly sophisticated ai model, but to demonstrate understanding of core concepts such as tokenization, statistical word prediction, and probability-based text generation.  the implementation focuses on a bigram model (n = 2), though the system can also be extended to support trigram or higher-order n-grams. the program reads a dataset from a text file, processes the text, trains the language model, and generates sentences based on learned word relationships.  this project demonstrates the basic principles behind language modeling and provides a foundation for understanding more advanced nlp models.  2. objectives of the project  the primary objective of this project is to design and implement a simple n-gram language model using python. the model should be able to learn patterns from a text dataset and generate new sentences based on those patterns.  the specific objectives of the project are as follows:  to understand the concept of language models in natural language processing.  to implement text preprocessing and tokenization.  to build an n-gram model that learns word patterns from the dataset.  to generate sentences using learned probabilities of word sequences.  to organize the implementation into clean and modular python functions.  to test the model by generating multiple example sentences.  by achieving these objectives, the project demonstrates basic machine learning concepts and python programming skills required for ai and nlp development.  3. technologies and tools used  the following technologies and tools were used to implement this project:  python 3  python was chosen as the primary programming language due to its simplicity, readability, and extensive ecosystem for data science and artificial intelligence.  python standard libraries  several built-in python libraries were used in the project:  collections – used to implement defaultdict for storing word relationships.  random – used for selecting the next word randomly from possible candidates.  re – used for text preprocessing and removing punctuation.  optional libraries  although not strictly required, libraries such as numpy and pandas can be used for more advanced data handling. in this project, the core implementation relies mainly on standard python libraries to keep the model simple and lightweight.  4. dataset preparation  the first step in building the language model is preparing the dataset. the dataset consists of a simple text file named dataset.txt, which contains multiple sentences related to technology, programming, and machine learning.  an example dataset used in this project is shown below:  machine learning is fascinating python is a powerful programming language machine learning uses data d ...

# %%
# remove numbers
text = re.sub(r'\d+', '', text)

# %%
# remove punctuation
text = re.sub(r'[^\w\s]', '', text)

# %%
# tokenize
tokens = text.split()

# %%
tokens
# Out:
# ['implementation',
#  'of',
#  'a',
#  'simple',
#  'ngram',
#  'language',
#  'model',
#  'using',
#  'python',
#  'introduction',
#  'language',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'fundamental',
#  'ways',
#  'humans',
#  'communicate',
#  'information',
#  'ideas',
#  'and',
#  'knowledge',
#  'in',
#  'the',
#  'field',
#  'of',
#  'artificial',
#  'intelligence',
#  'ai',
#  'and',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'enabling',
#  'computers',
#  'to',
#  'understand',
#  'and',
#  'generate',
#  'human',
#  'language',
#  'is',
#  'a',
#  'major',
#  'research',
#  'goal',
#  'one',
#  'important',
#  'concept',
#  'in',
#  'nlp',
#  'is',
#  'the',
#  'language',
#  'model',
#  'which',
#  'is',
#  'a',
#  'mathematical',
#  'model',
#  'that',
#  'predicts',
#  'the',
#  'probability',
#  'of',
#  'a',
#  'sequence',
#  'of',
#  'words',
#  'language',
#  'models',
#  'are',
#  'used',
#  'in',
#  'many',
#  'applications',
#  'such',
#  'as',
#  'chatbots',
#  'machine',
#  'translation',
#  'speech',
#  'recognition',
#  'text',
#  'prediction',
#  'and',
#  'virtual',
#  'assistants',
#  'a',
#  'language',
#  'model',
#  'learns',
#  'patterns',
#  'from',
#  'a',
#  'given',
#  'dataset',
#  'and',
#  'uses',
#  'these',
#  'patterns',
#  'to',
#  'generate',
#  'or',
#  'predict',
#  'text',
#  'modern',
#  'language',
#  'models',
#  'such',
#  'as',
#  'gpt',
#  'and',
#  'bert',
#  'rely',
#  'on',
#  'deep',
#  'learning',
#  'and',
#  'massive',
#  'datasets',
#  'however',
#  'before',
#  'the',
#  'rise',
#  'of',
#  'deep',
#  'learning',
#  'models',
#  'simpler',
#  'statistical',
#  'approaches',
#  'were',
#  'widely',
#  'used',
#  'one',
#  'of',
#  'the',
#  'most',
#  'important',
#  'and',
#  'fundamental',
#  'approaches',
#  'is',
#  'the',
#  'ngram',
#  'language',
#  'model',
#  'the',
#  'purpose',
#  'of',
#  'this',
#  'project',
#  'is',
#  'to',
#  'implement',
#  'a',
#  'simple',
#  'language',
#  'model',
#  'using',
#  'the',
#  'ngram',
#  'approach',
#  'in',
#  'python',
#  'the',
#  'model',
#  'learns',
#  'word',
#  'patterns',
#  'from',
#  'a',
#  'text',
#  'dataset',
#  'and',
#  'generates',
#  'new',
#  'sentences',
#  'based',
#  'on',
#  'the',
#  'learned',
#  'patterns',
#  'the',
#  'goal',
#  'of',
#  'this',
#  'assignment',
#  'is',
#  'not',
#  'to',
#  'build',
#  'a',
#  'highly',
#  'sophisticated',
#  'ai',
#  'model',
#  'but',
#  'to',
#  'demonstrate',
#  'understanding',
#  'of',
#  'core',
#  'concepts',
#  'such',
#  'as',
#  'tokenization',
#  'statistical',
#  'word',
#  'prediction',
#  'and',
#  'probabilitybased',
#  'text',
#  'generation',
#  'the',
#  'implementation',
#  'focuses',
#  'on',
#  'a',
#  'bigram',
#  'model',
#  'n',
#  'though',
#  'the',
#  'system',
#  'can',
#  'also',
#  'be',
#  'extended',
#  'to',
#  'support',
#  'trigram',
#  'or',
#  'higherorder',
#  'ngrams',
#  'the',
#  'program',
#  'reads',
#  'a',
#  'dataset',
#  'from',
#  'a',
#  'text',
#  'file',
#  'processes',
#  'the',
#  'text',
#  'trains',
#  'the',
#  'language',
#  'model',
#  'and',
#  'generates',
#  'sentences',
#  'based',
#  'on',
#  'learned',
#  'word',
#  'relationships',
#  'this',
#  'project',
#  'demonstrates',
#  'the',
#  'basic',
#  'principles',
#  'behind',
#  'language',
#  'modeling',
#  'and',
#  'provides',
#  'a',
#  'foundation',
#  'for',
#  'understanding',
#  'more',
#  'advanced',
#  'nlp',
#  'models',
#  'objectives',
#  'of',
#  'the',
#  'project',
#  'the',
#  'primary',
#  'objective',
#  'of',
#  'this',
#  'project',
#  'is',
#  'to',
#  'design',
#  'and',
#  'implement',
#  'a',
#  'simple',
#  'ngram',
#  'language',
#  'model',
#  'using',
#  'python',
#  'the',
#  'model',
#  'should',
#  'be',
#  'able',
#  'to',
#  'learn',
#  'patterns',
#  'from',
#  'a',
#  'text',
#  'dataset',
#  'and',
#  'generate',
#  'new',
#  'sentences',
#  'based',
#  'on',
#  'those',
#  'patterns',
#  'the',
#  'specific',
#  'objectives',
#  'of',
#  'the',
#  'project',
#  'are',
#  'as',
#  'follows',
#  'to',
#  'understand',
#  'the',
#  'concept',
#  'of',
#  'language',
#  'models',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'to',
#  'implement',
#  'text',
#  'preprocessing',
#  'and',
#  'tokenization',
#  'to',
#  'build',
#  'an',
#  'ngram',
#  'model',
#  'that',
#  'learns',
#  'word',
#  'patterns',
#  'from',
#  'the',
#  'dataset',
#  'to',
#  'generate',
#  'sentences',
#  'using',
#  'learned',
#  'probabilities',
#  'of',
#  'word',
#  'sequences',
#  'to',
#  'organize',
#  'the',
#  'implementation',
#  'into',
#  'clean',
#  'and',
#  'modular',
#  'python',
#  'functions',
#  'to',
#  'test',
#  'the',
#  'model',
#  'by',
#  'generating',
#  'multiple',
#  'example',
#  'sentences',
#  'by',
#  'achieving',
#  'these',
#  'objectives',
#  'the',
#  'project',
#  'demonstrates',
#  'basic',
#  'machine',
#  'learning',
#  'concepts',
#  'and',
#  'python',
#  'programming',
#  'skills',
#  'required',
#  'for',
#  'ai',
#  'and',
#  'nlp',
#  'development',
#  'technologies',
#  'and',
#  'tools',
#  'used',
#  'the',
#  'following',
#  'technologies',
#  'and',
#  'tools',
#  'were',
#  'used',
#  'to',
#  'implement',
#  'this',
#  'project',
#  'python',
#  'python',
#  'was',
#  'chosen',
#  'as',
#  'the',
#  'primary',
#  'programming',
#  'language',
#  'due',
#  'to',
#  'its',
#  'simplicity',
#  'readability',
#  'and',
#  'extensive',
#  'ecosystem',
#  'for',
#  'data',
#  'science',
#  'and',
#  'artificial',
#  'intelligence',
#  'python',
#  'standard',
#  'libraries',
#  'several',
#  'builtin',
#  'python',
#  'libraries',
#  'were',
#  'used',
#  'in',
#  'the',
#  'project',
#  'collections',
#  'used',
#  'to',
#  'implement',
#  'defaultdict',
#  'for',
#  'storing',
#  'word',
#  'relationships',
#  'random',
#  'used',
#  'for',
#  'selecting',
#  'the',
#  'next',
#  'word',
#  'randomly',
#  'from',
#  'possible',
#  'candidates',
#  're',
#  'used',
#  'for',
#  'text',
#  'preprocessing',
#  'and',
#  'removing',
#  'punctuation',
#  'optional',
#  'libraries',
#  'although',
#  'not',
#  'strictly',
#  'required',
#  'libraries',
#  'such',
#  'as',
#  'numpy',
#  'and',
#  'pandas',
#  'can',
#  'be',
#  'used',
#  'for',
#  'more',
#  'advanced',
#  'data',
#  'handling',
#  'in',
#  'this',
#  'project',
#  'the',
#  'core',
#  'implementation',
#  'relies',
#  'mainly',
#  'on',
#  'standard',
#  'python',
#  'libraries',
#  'to',
#  'keep',
#  'the',
#  'model',
#  'simple',
#  'and',
#  'lightweight',
#  'dataset',
#  'preparation',
#  'the',
#  'first',
#  'step',
#  'in',
#  'building',
#  'the',
#  'language',
#  'model',
#  'is',
#  'preparing',
#  'the',
#  'dataset',
#  'the',
#  'dataset',
#  'consists',
#  'of',
#  'a',
#  'simple',
#  'text',
#  'file',
#  'named',
#  'datasettxt',
#  'which',
#  'contains',
#  'multiple',
#  'sentences',
#  'related',
#  'to',
#  'technology',
#  'programming',
#  'and',
#  'machine',
#  'learning',
#  'an',
#  'example',
#  'dataset',
#  'used',
#  'in',
#  'this',
#  'project',
#  'is',
#  'shown',
#  'below',
#  'machine',
#  'learning',
#  'is',
#  'fascinating',
#  'python',
#  'is',
#  'a',
#  'powerful',
#  'programming',
#  'language',
#  'machine',
#  'learning',
#  'uses',
#  'data',
#  'data',
#  'science',
#  'uses',
#  'machine',
#  'learning',
#  'python',
#  'is',
#  'widely',
#  'used',
#  'in',
#  'data',
#  'science',
#  'artificial',
#  'intelligence',
#  'is',
#  'transforming',
#  'technology',
#  'the',
#  'dataset',
#  'does',
#  'not',
#  'need',
#  'to',
#  'be',
#  'very',
#  'large',
#  'because',
#  'the',
#  'goal',
#  'of',
#  'this',
#  'project',
#  'is',
#  'to',
#  'demonstrate',
#  'the',
#  'concept',
#  'of',
#  'an',
#  'ngram',
#  'model',
#  'rather',
#  'than',
#  'train',
#  'a',
#  'productionlevel',
#  'system',
#  'however',
#  'the',
#  'dataset',
#  'should',
#  'contain',
#  'several',
#  'sentences',
#  'so',
#  'that',
#  'the',
#  'model',
#  'can',
#  'learn',
#  'meaningful',
#  'word',
#  'patterns',
#  'the',
#  'dataset',
#  'is',
#  'stored',
#  'in',
#  'a',
#  'text',
#  'file',
#  'and',
#  'is',
#  'loaded',
#  'by',
#  'the',
#  'python',
#  'program',
#  'during',
#  'execution',
#  'text',
#  'processing',
#  'and',
#  'tokenization',
#  'before',
#  'training',
#  'the',
#  'model',
#  'the',
#  'text',
#  'must',
#  'be',
#  'processed',
#  'and',
#  'converted',
#  'into',
#  'a',
#  'format',
#  'suitable',
#  'for',
#  'analysis',
#  'this',
#  'process',
#  'is',
#  'called',
#  'text',
#  'preprocessing',
#  'the',
#  'preprocessing',
#  'steps',
#  'include',
#  'reading',
#  'the',
#  'dataset',
#  'from',
#  'the',
#  'file',
#  'converting',
#  'all',
#  'text',
#  'to',
#  'lowercase',
#  'removing',
#  'punctuation',
#  'and',
#  'special',
#  'characters',
#  'breaking',
#  'the',
#  'text',
#  'into',
#  'individual',
#  'words',
#  'tokenization',
#  'tokenization',
#  'is',
#  'an',
#  'important',
#  'step',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'because',
#  'it',
#  'converts',
#  'raw',
#  'text',
#  'into',
#  'smaller',
#  'units',
#  'called',
#  'tokens',
#  'which',
#  'can',
#  'be',
#  'words',
#  'or',
#  'subwords',
#  'for',
#  'example',
#  'consider',
#  'the',
#  'sentence',
#  'machine',
#  'learning',
#  'is',
#  'powerful',
#  'after',
#  'tokenization',
#  'the',
#  'sentence',
#  'becomes',
#  'machine',
#  'learning',
#  'is',
#  'powerful',
#  'these',
#  'tokens',
#  'are',
#  'then',
#  'used',
#  'to',
#  'build',
#  'the',
#  'ngram',
#  'model',
#  'ngram',
#  'language',
#  'model',
#  'an',
#  'ngram',
#  'model',
#  'is',
#  'a',
#  'statistical',
#  'language',
#  'model',
#  'that',
#  'predicts',
#  'the',
#  'next',
#  'word',
#  'in',
#  'a',
#  'sequence',
#  'based',
#  'on',
#  'the',
#  'previous',
#  'words',
#  'the',
#  'value',
#  'n',
#  'represents',
#  'the',
#  'number',
#  'of',
#  'words',
#  'considered',
#  'in',
#  'the',
#  'sequence',
#  'types',
#  'of',
#  'ngrams',
#  'unigram',
#  'n',
#  'a',
#  'unigram',
#  'model',
#  'considers',
#  'each',
#  'word',
#  'independently',
#  'example',
#  'machine',
#  'learning',
#  'is',
#  'powerful',
#  'bigram',
#  'n',
#  'a',
#  'bigram',
#  'model',
#  'considers',
#  'the',
#  'current',
#  'word',
#  'and',
#  'the',
#  'next',
#  'word',
#  'example',
#  'machine',
#  'learning',
#  'learning',
#  'is',
#  'is',
#  'powerful',
#  'trigram',
#  'n',
#  'a',
#  'trigram',
#  'model',
#  'considers',
#  'two',
#  'previous',
#  'words',
#  'to',
#  'predict',
#  'the',
#  'next',
#  'word',
#  'example',
#  'machine',
#  'learning',
#  'is',
#  'learning',
#  'is',
#  'powerful',
#  'in',
#  'this',
#  'project',
#  'a',
#  'bigram',
#  'model',
#  'is',
#  'implemented',
#  'because',
#  'it',
#  'provides',
#  'a',
#  'balance',
#  'between',
#  'simplicity',
#  'and',
#  'effectiveness',
#  'model',
#  'training',
#  'once',
#  'the',
#  'dataset',
#  'has',
#  'been',
#  'tokenized',
#  'the',
#  'next',
#  'step',
#  'is',
#  'to',
#  'train',
#  'the',
#  'ngram',
#  'model',
#  'training',
#  'involves',
#  'analyzing',
#  'the',
#  'sequence',
#  'of',
#  'words',
#  'and',
#  'storing',
#  'the',
#  'relationships',
#  'between',
#  'words',
#  'specifically',
#  'the',
#  'model',
#  'records',
#  'which',
#  'words',
#  'commonly',
#  'follow',
#  'a',
#  'given',
#  'word',
#  'for',
#  'example',
#  'consider',
#  'the',
#  'sentence',
#  'machine',
#  'learning',
#  'is',
#  'powerful',
#  'the',
#  'bigram',
#  'pairs',
#  'would',
#  'be',
#  'machine',
#  'learning',
#  'learning',
#  'is',
#  'is',
#  'powerful',
#  'these',
#  'relationships',
#  'are',
#  'stored',
#  'using',
#  'a',
#  'python',
#  'dictionary',
#  'structure',
#  'to',
#  'make',
#  'this',
#  'process',
#  'efficient',
#  'the',
#  'project',
#  'uses',
#  'defaultdict',
#  'from',
#  'the',
#  'collections',
#  'module',
#  'this',
#  'allows',
#  'new',
#  'keys',
#  'to',
#  'be',
#  'created',
#  'automatically',
#  'when',
#  'storing',
#  'word',
#  'sequences',
#  'the',
#  'model',
#  'essentially',
#  'builds',
#  'a',
#  'mapping',
#  'such',
#  'as',
#  'machine',
#  'learning',
#  'learning',
#  'is',
#  'is',
#  'powerful',
#  'if',
#  'multiple',
#  'sentences',
#  'contain',
#  'the',
#  'same',
#  ...]

# %%
len(tokens)
# Out:
# 1577

# %% [markdown]
# # vocab

# %%
vocab = sorted(set(tokens))

word_to_idx = {word:i for i,word in enumerate(vocab)}

idx_to_word = {i:word for word,i in word_to_idx.items()}

len(vocab)
# Out:
# 438

# %%
word_to_idx
# Out:
# {'a': 0,
#  'able': 1,
#  'achieving': 2,
#  'across': 3,
#  'advanced': 4,
#  'after': 5,
#  'ai': 6,
#  'all': 7,
#  'allows': 8,
#  'also': 9,
#  'although': 10,
#  'always': 11,
#  'among': 12,
#  'an': 13,
#  'analysis': 14,
#  'analyzing': 15,
#  'and': 16,
#  'anyone': 17,
#  'applications': 18,
#  'approach': 19,
#  'approaches': 20,
#  'architectures': 21,
#  'are': 22,
#  'artificial': 23,
#  'as': 24,
#  'assignment': 25,
#  'assistants': 26,
#  'automatically': 27,
#  'balance': 28,
#  'based': 29,
#  'basic': 30,
#  'be': 31,
#  'because': 32,
#  'becomes': 33,
#  'been': 34,
#  'before': 35,
#  'behind': 36,
#  'below': 37,
#  'bert': 38,
#  'between': 39,
#  'bigram': 40,
#  'breaking': 41,
#  'build': 42,
#  'building': 43,
#  'builds': 44,
#  'builtin': 45,
#  'but': 46,
#  'by': 47,
#  'called': 48,
#  'can': 49,
#  'candidates': 50,
#  'cannot': 51,
#  'capture': 52,
#  'career': 53,
#  'challenges': 54,
#  'characters': 55,
#  'chatbots': 56,
#  'checks': 57,
#  'choose': 58,
#  'chooses': 59,
#  'chosen': 60,
#  'clean': 61,
#  'code': 62,
#  'collections': 63,
#  'combinations': 64,
#  'commonly': 65,
#  'communicate': 66,
#  'compared': 67,
#  'computers': 68,
#  'concept': 69,
#  'concepts': 70,
#  'conclusion': 71,
#  'consider': 72,
#  'considered': 73,
#  'considers': 74,
#  'consists': 75,
#  'contain': 76,
#  'contains': 77,
#  'context': 78,
#  'converted': 79,
#  'converting': 80,
#  'converts': 81,
#  'core': 82,
#  'could': 83,
#  'created': 84,
#  'current': 85,
#  'data': 86,
#  'dataset': 87,
#  'datasets': 88,
#  'datasettxt': 89,
#  'deep': 90,
#  'defaultdict': 91,
#  'demonstrate': 92,
#  'demonstrates': 93,
#  'dependencies': 94,
#  'design': 95,
#  'desired': 96,
#  'despite': 97,
#  'development': 98,
#  'dictionary': 99,
#  'different': 100,
#  'divided': 101,
#  'do': 102,
#  'does': 103,
#  'due': 104,
#  'during': 105,
#  'each': 106,
#  'easy': 107,
#  'ecosystem': 108,
#  'effectiveness': 109,
#  'efficient': 110,
#  'enabling': 111,
#  'encountered': 112,
#  'engineering': 113,
#  'ensure': 114,
#  'essentially': 115,
#  'example': 116,
#  'executed': 117,
#  'execution': 118,
#  'extend': 119,
#  'extended': 120,
#  'extensive': 121,
#  'faced': 122,
#  'fascinating': 123,
#  'field': 124,
#  'file': 125,
#  'final': 126,
#  'first': 127,
#  'focuses': 128,
#  'follow': 129,
#  'following': 130,
#  'follows': 131,
#  'for': 132,
#  'format': 133,
#  'foundation': 134,
#  'foundational': 135,
#  'from': 136,
#  'full': 137,
#  'function': 138,
#  'functions': 139,
#  'fundamental': 140,
#  'future': 141,
#  'generate': 142,
#  'generate_text': 143,
#  'generated': 144,
#  'generates': 145,
#  'generating': 146,
#  'generation': 147,
#  'given': 148,
#  'goal': 149,
#  'good': 150,
#  'gpt': 151,
#  'grammar': 152,
#  'grammatical': 153,
#  'handling': 154,
#  'has': 155,
#  'have': 156,
#  'higherorder': 157,
#  'highly': 158,
#  'how': 159,
#  'however': 160,
#  'human': 161,
#  'humans': 162,
#  'ideas': 163,
#  'if': 164,
#  'implement': 165,
#  'implementation': 166,
#  'implemented': 167,
#  'implementing': 168,
#  'important': 169,
#  'improvements': 170,
#  'improves': 171,
#  'in': 172,
#  'include': 173,
#  'included': 174,
#  'incomplete': 175,
#  'increases': 176,
#  'independently': 177,
#  'individual': 178,
#  'information': 179,
#  'insight': 180,
#  'intelligence': 181,
#  'into': 182,
#  'introducing': 183,
#  'introduction': 184,
#  'involves': 185,
#  'is': 186,
#  'it': 187,
#  'its': 188,
#  'keep': 189,
#  'key': 190,
#  'keys': 191,
#  'knowledge': 192,
#  'lack': 193,
#  'language': 194,
#  'large': 195,
#  'larger': 196,
#  'learn': 197,
#  'learned': 198,
#  'learning': 199,
#  'learns': 200,
#  'length': 201,
#  'libraries': 202,
#  'lightweight': 203,
#  'limitations': 204,
#  'limited': 205,
#  'load_dataset': 206,
#  'loaded': 207,
#  'local': 208,
#  'longrange': 209,
#  'lowercase': 210,
#  'machine': 211,
#  'mainly': 212,
#  'maintainable': 213,
#  'major': 214,
#  'make': 215,
#  'many': 216,
#  'mapping': 217,
#  'massive': 218,
#  'mathematical': 219,
#  'may': 220,
#  'meaning': 221,
#  'meaningful': 222,
#  'methods': 223,
#  'model': 224,
#  'modeling': 225,
#  'models': 226,
#  'modern': 227,
#  'modular': 228,
#  'module': 229,
#  'more': 230,
#  'most': 231,
#  'multiple': 232,
#  'must': 233,
#  'n': 234,
#  'named': 235,
#  'natural': 236,
#  'need': 237,
#  'new': 238,
#  'next': 239,
#  'ngram': 240,
#  'ngrams': 241,
#  'nlp': 242,
#  'not': 243,
#  'number': 244,
#  'numpy': 245,
#  'nvalues': 246,
#  'objective': 247,
#  'objectives': 248,
#  'of': 249,
#  'on': 250,
#  'once': 251,
#  'one': 252,
#  'only': 253,
#  'optional': 254,
#  'or': 255,
#  'organize': 256,
#  'organizing': 257,
#  'output': 258,
#  'outputs': 259,
#  'overall': 260,
#  'overcome': 261,
#  'pairs': 262,
#  'pandas': 263,
#  'patterns': 264,
#  'perfectly': 265,
#  'perform': 266,
#  'possible': 267,
#  'powerful': 268,
#  'practical': 269,
#  'practices': 270,
#  'predict': 271,
#  'prediction': 272,
#  'predicts': 273,
#  'preparation': 274,
#  'preparing': 275,
#  'preprocessing': 276,
#  'previous': 277,
#  'primary': 278,
#  'principles': 279,
#  'probabilities': 280,
#  'probability': 281,
#  'probabilitybased': 282,
#  'process': 283,
#  'processed': 284,
#  'processes': 285,
#  'processing': 286,
#  'productionlevel': 287,
#  'program': 288,
#  'programming': 289,
#  'project': 290,
#  'provides': 291,
#  'punctuation': 292,
#  'purpose': 293,
#  'pursuing': 294,
#  'python': 295,
#  'random': 296,
#  'randomly': 297,
#  'randomness': 298,
#  'rapidly': 299,
#  'rather': 300,
#  'raw': 301,
#  're': 302,
#  'reached': 303,
#  'readability': 304,
#  'readable': 305,
#  'reading': 306,
#  'reads': 307,
#  'realistic': 308,
#  'recognition': 309,
#  'records': 310,
#  'related': 311,
#  'relationships': 312,
#  'relatively': 313,
#  'relies': 314,
#  'rely': 315,
#  'remains': 316,
#  'removing': 317,
#  'repeats': 318,
#  'repetitive': 319,
#  'represents': 320,
#  'require': 321,
#  'required': 322,
#  'research': 323,
#  'restricts': 324,
#  'result': 325,
#  'returns': 326,
#  'rise': 327,
#  'runs': 328,
#  'same': 329,
#  'science': 330,
#  'selected': 331,
#  'selecting': 332,
#  'selection': 333,
#  'selects': 334,
#  'sentence': 335,
#  'sentences': 336,
#  'sequence': 337,
#  'sequences': 338,
#  'several': 339,
#  'should': 340,
#  'shown': 341,
#  'simple': 342,
#  'simpler': 343,
#  'simplicity': 344,
#  'simply': 345,
#  'since': 346,
#  'skills': 347,
#  'slightly': 348,
#  'small': 349,
#  'smaller': 350,
#  'so': 351,
#  'software': 352,
#  'sophisticated': 353,
#  'special': 354,
#  'specific': 355,
#  'specifically': 356,
#  'speech': 357,
#  'splitting': 358,
#  'standard': 359,
#  'starting': 360,
#  'statistical': 361,
#  'step': 362,
#  'steps': 363,
#  'still': 364,
#  'stored': 365,
#  'stores': 366,
#  'storing': 367,
#  'strictly': 368,
#  'structure': 369,
#  'subwords': 370,
#  'successfully': 371,
#  'such': 372,
#  'suitable': 373,
#  'support': 374,
#  'system': 375,
#  'systems': 376,
#  'techniques': 377,
#  'technologies': 378,
#  'technology': 379,
#  'test': 380,
#  'text': 381,
#  'than': 382,
#  'that': 383,
#  'the': 384,
#  'them': 385,
#  'then': 386,
#  'these': 387,
#  'they': 388,
#  'this': 389,
#  'those': 390,
#  'though': 391,
#  'to': 392,
#  'tokenization': 393,
#  'tokenize_text': 394,
#  'tokenized': 395,
#  'tokens': 396,
#  'tools': 397,
#  'train': 398,
#  'train_model': 399,
#  'trained': 400,
#  'training': 401,
#  'trains': 402,
#  'transformers': 403,
#  'transforming': 404,
#  'translation': 405,
#  'trigram': 406,
#  'two': 407,
#  'types': 408,
#  'understand': 409,
#  'understanding': 410,
#  'unigram': 411,
#  'units': 412,
#  'until': 413,
#  'used': 414,
#  'useful': 415,
#  'uses': 416,
#  'using': 417,
#  'valuable': 418,
#  'value': 419,
#  'vary': 420,
#  'very': 421,
#  'virtual': 422,
#  'was': 423,
#  'way': 424,
#  'ways': 425,
#  'well': 426,
#  'were': 427,
#  'when': 428,
#  'which': 429,
#  'while': 430,
#  'widely': 431,
#  'with': 432,
#  'word': 433,
#  'words': 434,
#  'work': 435,
#  'works': 436,
#  'would': 437}

# %%
word_to_idx
# Out:
# {'a': 0,
#  'able': 1,
#  'achieving': 2,
#  'across': 3,
#  'advanced': 4,
#  'after': 5,
#  'ai': 6,
#  'all': 7,
#  'allows': 8,
#  'also': 9,
#  'although': 10,
#  'always': 11,
#  'among': 12,
#  'an': 13,
#  'analysis': 14,
#  'analyzing': 15,
#  'and': 16,
#  'anyone': 17,
#  'applications': 18,
#  'approach': 19,
#  'approaches': 20,
#  'architectures': 21,
#  'are': 22,
#  'artificial': 23,
#  'as': 24,
#  'assignment': 25,
#  'assistants': 26,
#  'automatically': 27,
#  'balance': 28,
#  'based': 29,
#  'basic': 30,
#  'be': 31,
#  'because': 32,
#  'becomes': 33,
#  'been': 34,
#  'before': 35,
#  'behind': 36,
#  'below': 37,
#  'bert': 38,
#  'between': 39,
#  'bigram': 40,
#  'breaking': 41,
#  'build': 42,
#  'building': 43,
#  'builds': 44,
#  'builtin': 45,
#  'but': 46,
#  'by': 47,
#  'called': 48,
#  'can': 49,
#  'candidates': 50,
#  'cannot': 51,
#  'capture': 52,
#  'career': 53,
#  'challenges': 54,
#  'characters': 55,
#  'chatbots': 56,
#  'checks': 57,
#  'choose': 58,
#  'chooses': 59,
#  'chosen': 60,
#  'clean': 61,
#  'code': 62,
#  'collections': 63,
#  'combinations': 64,
#  'commonly': 65,
#  'communicate': 66,
#  'compared': 67,
#  'computers': 68,
#  'concept': 69,
#  'concepts': 70,
#  'conclusion': 71,
#  'consider': 72,
#  'considered': 73,
#  'considers': 74,
#  'consists': 75,
#  'contain': 76,
#  'contains': 77,
#  'context': 78,
#  'converted': 79,
#  'converting': 80,
#  'converts': 81,
#  'core': 82,
#  'could': 83,
#  'created': 84,
#  'current': 85,
#  'data': 86,
#  'dataset': 87,
#  'datasets': 88,
#  'datasettxt': 89,
#  'deep': 90,
#  'defaultdict': 91,
#  'demonstrate': 92,
#  'demonstrates': 93,
#  'dependencies': 94,
#  'design': 95,
#  'desired': 96,
#  'despite': 97,
#  'development': 98,
#  'dictionary': 99,
#  'different': 100,
#  'divided': 101,
#  'do': 102,
#  'does': 103,
#  'due': 104,
#  'during': 105,
#  'each': 106,
#  'easy': 107,
#  'ecosystem': 108,
#  'effectiveness': 109,
#  'efficient': 110,
#  'enabling': 111,
#  'encountered': 112,
#  'engineering': 113,
#  'ensure': 114,
#  'essentially': 115,
#  'example': 116,
#  'executed': 117,
#  'execution': 118,
#  'extend': 119,
#  'extended': 120,
#  'extensive': 121,
#  'faced': 122,
#  'fascinating': 123,
#  'field': 124,
#  'file': 125,
#  'final': 126,
#  'first': 127,
#  'focuses': 128,
#  'follow': 129,
#  'following': 130,
#  'follows': 131,
#  'for': 132,
#  'format': 133,
#  'foundation': 134,
#  'foundational': 135,
#  'from': 136,
#  'full': 137,
#  'function': 138,
#  'functions': 139,
#  'fundamental': 140,
#  'future': 141,
#  'generate': 142,
#  'generate_text': 143,
#  'generated': 144,
#  'generates': 145,
#  'generating': 146,
#  'generation': 147,
#  'given': 148,
#  'goal': 149,
#  'good': 150,
#  'gpt': 151,
#  'grammar': 152,
#  'grammatical': 153,
#  'handling': 154,
#  'has': 155,
#  'have': 156,
#  'higherorder': 157,
#  'highly': 158,
#  'how': 159,
#  'however': 160,
#  'human': 161,
#  'humans': 162,
#  'ideas': 163,
#  'if': 164,
#  'implement': 165,
#  'implementation': 166,
#  'implemented': 167,
#  'implementing': 168,
#  'important': 169,
#  'improvements': 170,
#  'improves': 171,
#  'in': 172,
#  'include': 173,
#  'included': 174,
#  'incomplete': 175,
#  'increases': 176,
#  'independently': 177,
#  'individual': 178,
#  'information': 179,
#  'insight': 180,
#  'intelligence': 181,
#  'into': 182,
#  'introducing': 183,
#  'introduction': 184,
#  'involves': 185,
#  'is': 186,
#  'it': 187,
#  'its': 188,
#  'keep': 189,
#  'key': 190,
#  'keys': 191,
#  'knowledge': 192,
#  'lack': 193,
#  'language': 194,
#  'large': 195,
#  'larger': 196,
#  'learn': 197,
#  'learned': 198,
#  'learning': 199,
#  'learns': 200,
#  'length': 201,
#  'libraries': 202,
#  'lightweight': 203,
#  'limitations': 204,
#  'limited': 205,
#  'load_dataset': 206,
#  'loaded': 207,
#  'local': 208,
#  'longrange': 209,
#  'lowercase': 210,
#  'machine': 211,
#  'mainly': 212,
#  'maintainable': 213,
#  'major': 214,
#  'make': 215,
#  'many': 216,
#  'mapping': 217,
#  'massive': 218,
#  'mathematical': 219,
#  'may': 220,
#  'meaning': 221,
#  'meaningful': 222,
#  'methods': 223,
#  'model': 224,
#  'modeling': 225,
#  'models': 226,
#  'modern': 227,
#  'modular': 228,
#  'module': 229,
#  'more': 230,
#  'most': 231,
#  'multiple': 232,
#  'must': 233,
#  'n': 234,
#  'named': 235,
#  'natural': 236,
#  'need': 237,
#  'new': 238,
#  'next': 239,
#  'ngram': 240,
#  'ngrams': 241,
#  'nlp': 242,
#  'not': 243,
#  'number': 244,
#  'numpy': 245,
#  'nvalues': 246,
#  'objective': 247,
#  'objectives': 248,
#  'of': 249,
#  'on': 250,
#  'once': 251,
#  'one': 252,
#  'only': 253,
#  'optional': 254,
#  'or': 255,
#  'organize': 256,
#  'organizing': 257,
#  'output': 258,
#  'outputs': 259,
#  'overall': 260,
#  'overcome': 261,
#  'pairs': 262,
#  'pandas': 263,
#  'patterns': 264,
#  'perfectly': 265,
#  'perform': 266,
#  'possible': 267,
#  'powerful': 268,
#  'practical': 269,
#  'practices': 270,
#  'predict': 271,
#  'prediction': 272,
#  'predicts': 273,
#  'preparation': 274,
#  'preparing': 275,
#  'preprocessing': 276,
#  'previous': 277,
#  'primary': 278,
#  'principles': 279,
#  'probabilities': 280,
#  'probability': 281,
#  'probabilitybased': 282,
#  'process': 283,
#  'processed': 284,
#  'processes': 285,
#  'processing': 286,
#  'productionlevel': 287,
#  'program': 288,
#  'programming': 289,
#  'project': 290,
#  'provides': 291,
#  'punctuation': 292,
#  'purpose': 293,
#  'pursuing': 294,
#  'python': 295,
#  'random': 296,
#  'randomly': 297,
#  'randomness': 298,
#  'rapidly': 299,
#  'rather': 300,
#  'raw': 301,
#  're': 302,
#  'reached': 303,
#  'readability': 304,
#  'readable': 305,
#  'reading': 306,
#  'reads': 307,
#  'realistic': 308,
#  'recognition': 309,
#  'records': 310,
#  'related': 311,
#  'relationships': 312,
#  'relatively': 313,
#  'relies': 314,
#  'rely': 315,
#  'remains': 316,
#  'removing': 317,
#  'repeats': 318,
#  'repetitive': 319,
#  'represents': 320,
#  'require': 321,
#  'required': 322,
#  'research': 323,
#  'restricts': 324,
#  'result': 325,
#  'returns': 326,
#  'rise': 327,
#  'runs': 328,
#  'same': 329,
#  'science': 330,
#  'selected': 331,
#  'selecting': 332,
#  'selection': 333,
#  'selects': 334,
#  'sentence': 335,
#  'sentences': 336,
#  'sequence': 337,
#  'sequences': 338,
#  'several': 339,
#  'should': 340,
#  'shown': 341,
#  'simple': 342,
#  'simpler': 343,
#  'simplicity': 344,
#  'simply': 345,
#  'since': 346,
#  'skills': 347,
#  'slightly': 348,
#  'small': 349,
#  'smaller': 350,
#  'so': 351,
#  'software': 352,
#  'sophisticated': 353,
#  'special': 354,
#  'specific': 355,
#  'specifically': 356,
#  'speech': 357,
#  'splitting': 358,
#  'standard': 359,
#  'starting': 360,
#  'statistical': 361,
#  'step': 362,
#  'steps': 363,
#  'still': 364,
#  'stored': 365,
#  'stores': 366,
#  'storing': 367,
#  'strictly': 368,
#  'structure': 369,
#  'subwords': 370,
#  'successfully': 371,
#  'such': 372,
#  'suitable': 373,
#  'support': 374,
#  'system': 375,
#  'systems': 376,
#  'techniques': 377,
#  'technologies': 378,
#  'technology': 379,
#  'test': 380,
#  'text': 381,
#  'than': 382,
#  'that': 383,
#  'the': 384,
#  'them': 385,
#  'then': 386,
#  'these': 387,
#  'they': 388,
#  'this': 389,
#  'those': 390,
#  'though': 391,
#  'to': 392,
#  'tokenization': 393,
#  'tokenize_text': 394,
#  'tokenized': 395,
#  'tokens': 396,
#  'tools': 397,
#  'train': 398,
#  'train_model': 399,
#  'trained': 400,
#  'training': 401,
#  'trains': 402,
#  'transformers': 403,
#  'transforming': 404,
#  'translation': 405,
#  'trigram': 406,
#  'two': 407,
#  'types': 408,
#  'understand': 409,
#  'understanding': 410,
#  'unigram': 411,
#  'units': 412,
#  'until': 413,
#  'used': 414,
#  'useful': 415,
#  'uses': 416,
#  'using': 417,
#  'valuable': 418,
#  'value': 419,
#  'vary': 420,
#  'very': 421,
#  'virtual': 422,
#  'was': 423,
#  'way': 424,
#  'ways': 425,
#  'well': 426,
#  'were': 427,
#  'when': 428,
#  'which': 429,
#  'while': 430,
#  'widely': 431,
#  'with': 432,
#  'word': 433,
#  'words': 434,
#  'work': 435,
#  'works': 436,
#  'would': 437}

# %% [markdown]
# #Step 4 – Build an NGram Model

# %%
def train_model(tokens, word_to_idx, n=2):

    vocab_size = len(word_to_idx)

    matrix = torch.zeros((vocab_size, vocab_size))

    for i in range(len(tokens)-1):

        w1 = tokens[i]
        w2 = tokens[i+1]

        idx1 = word_to_idx[w1]
        idx2 = word_to_idx[w2]

        matrix[idx1][idx2] += 1

    # convert counts → probabilities

    prob_matrix = matrix / matrix.sum(dim=1, keepdim=True)

    return prob_matrix

# %%
prob_matrix = train_model(tokens, word_to_idx)
print(prob_matrix[0].shape)
print(prob_matrix[0][28])
# Out:
# torch.Size([438])
# tensor(0.0270)

# %%
vocab_size = len(idx_to_word)

current_idx = random.randint(0, vocab_size-1)

sentence = [idx_to_word[current_idx]]
sentence
# Out:
# ['its']

# %%
word_to_idx['dictionary']
# Out:
# 99

# %%
vocab_size
# Out:
# 438

# %%
current_idx = random.randint(0, vocab_size-1)
current_idx
# Out:
# 254

# %%
sentence = [idx_to_word[current_idx]]
sentence
# Out:
# ['optional']

# %%
probs = prob_matrix[current_idx]

next_idx = torch.multinomial(probs,1).item()

sentence.append(idx_to_word[next_idx])

current_idx = next_idx
sentence
# Out:
# ['optional', 'libraries']

# %% [markdown]
# # Generate Text Function

# %%
def generate_text(prob_matrix, idx_to_word, word_to_idx, length=10):

    vocab_size = len(idx_to_word)

    current_idx = random.randint(0, vocab_size-1)

    sentence = [idx_to_word[current_idx]]

    for _ in range(length):

        probs = prob_matrix[current_idx]

        next_idx = torch.multinomial(probs,1).item()

        sentence.append(idx_to_word[next_idx])

        current_idx = next_idx

    return " ".join(sentence)

# %%
for i in range(5):
    print(generate_text(prob_matrix, idx_to_word, word_to_idx))
# Out:
# units called text generation by removing punctuation and storing word independently
# by organizing the model is transforming technology the previous words randomly
# extended to keep the ngram model still demonstrates the language model
# but to implement a simple compared to generate sentences based on
# all possible next words is powerful if multiple sentences based on
